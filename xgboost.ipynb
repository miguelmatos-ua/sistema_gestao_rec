# %% [markdown]
# ## XGBoost
#
# The goal of this notebook is to test the XGBoost model on the BANES dataset, merged with the weather data.
#
# Different planned models (all of them w/ the weather data):
#
# - XGBoost with the weather data
# - day of week as a feature, hour and day of year.
# - is_weekend as a feature, hour and day of year.
# - Use the last 24 hours
# - Use the last 5-10 days of data at the same time.
#
# In order to repeat the data the least, we will pre-process the 3 dataframes, before we use the XGBoost model.

# %%
# import tqdm - progress bar
from tqdm import tqdm

# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# import xgboost
import xgboost as xgb

# import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

pd.options.mode.chained_assignment = None  # default='warn'
# Out:
# /home/mcmatos/.local/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
df = pd.read_csv('BANES_weather_merged.csv', parse_dates=['time'])
# remove duplicates
df = df.groupby(['time', 'location', 'postcode']).mean().reset_index()
df.head()
# Out:
#                  time                               location postcode  energy  \
# 0 2006-10-01 00:30:00    Guildhall Electricity Supply 1 (HH)  BA1 5AW    32.8
# 1 2006-10-01 01:00:00    Guildhall Electricity Supply 1 (HH)  BA1 5AW    33.0
# 2 2006-10-01 01:30:00  Bath Central Library Electricity (HH)  BA1 5AL     5.9
# 3 2006-10-01 01:30:00    Guildhall Electricity Supply 1 (HH)  BA1 5AW    32.7
# 4 2006-10-01 02:00:00    Guildhall Electricity Supply 1 (HH)  BA1 5AW    32.2
#
#     temp   dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  coco
# 0  14.95  13.80  93.0   0.0   0.0  175.0  13.9   NaN  1001.8   NaN
# 1  14.80  13.50  92.0   0.0   0.0  180.0  14.8   NaN  1001.7   NaN
# 2  14.75  13.35  91.5   0.0   0.0  180.0  13.9   NaN  1001.7   NaN
# 3  14.75  13.35  91.5   0.0   0.0  180.0  13.9   NaN  1001.7   NaN
# 4  14.70  13.20  91.0   0.0   0.0  180.0  13.0   NaN  1001.7   NaN

# %% [markdown]
# ##### Help functions
#
# Help functions for pre-processing, building, and plotting the model.

# %%
def pre_processing(df: pd.DataFrame, X_columns, y_columns, random=True, test_size=0.2):
    """ Pre-processing function

    This function takes a dataframe and splits it into X and y. 
    It also splits the data into train and test.

    Args:
        df: pandas dataframe
        X_columns: list of columns to be used as X
        y_columns: list of columns to be used as y
        random: boolean, if True, randomize the dataframe
        test_size: float, the size of the test set

    Returns:
        X_train: numpy array of X_train
        X_test: numpy array of X_test
        y_train: numpy array of y_train
        y_test: numpy array of y_test
    """
    X = df[X_columns]
    y = df[y_columns]

    if random:
        # split into train and test
        X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=test_size, random_state=42)
    else:
        # get first train size of data as train
        X_train = X.iloc[:int(X.shape[0] * (1 - test_size))]
        y_train = y.iloc[:int(y.shape[0] * (1 - test_size))]
        # get remaining data as test
        X_test = X.iloc[int(X.shape[0] * (1 - test_size)):]
        y_test = y.iloc[int(y.shape[0] * (1 - test_size)):]

    return X_train, X_test, y_train, y_test


def build_model(X_train: np.array, y_train: np.array, X_test: np.array):
    """
    This function builds a model.

    Args:
        X_train: numpy array of X_train
        y_train: numpy array of y_train
        X_test: numpy array of X_test

    Returns:
        model: xgboost model
        preds: numpy array of predictions
    """
    # set parameters
    params = {
        'max_depth': 5,
        'eta': 0.1,
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'verbosity': 1,
        'seed': 42
    }

    # train model
    model = xgb.train(params, xgb.DMatrix(X_train, label=y_train), num_boost_round=100)

    # make predictions
    preds = model.predict(xgb.DMatrix(X_test))

    return model, preds


def plot_results(preds: np.array, actuals: np.array, title: str):
    """ Plotting function

    This function plots the predicted and actual values.

    Args:
        preds: numpy array of predicted values
        actuals: numpy array of actual values
    """
    plt.scatter(actuals, preds, c='b', label='predicted')
    plt.xlabel('actual')
    plt.ylabel('predicted')
    plt.title(title)
    plt.xlim(0, plt.xlim()[1])
    plt.ylim(0, plt.ylim()[1])
    _ = plt.plot([0, 100], [0, 100], '--r', label='y=x')
    plt.legend()
    plt.show()


def performance_metrics(preds: np.array, actuals: np.array):
    """ Performance metrics function

    This function calculates the performance metrics.

    Args:
        preds: numpy array of predicted values
        actuals: numpy array of actual values
    """
    # calculate performance metrics
    mse = mean_squared_error(actuals, preds)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(actuals, preds)
    r2 = r2_score(actuals, preds)

    # print performance metrics
    print('MSE: %.4f' % mse)
    print('RMSE: %.4f' % rmse)
    print('MAE: %.4f' % mae)
    print('R2: %.4f' % r2)

# %% [markdown]
# ### First Model
#
# Predict using only the weather data, i.e., the humidity, temperature, wind speed, and pressure.

# %%
df1 = df[['energy', 'temp', 'rhum', 'wspd', 'pres']]
df1.head()
# Out:
#    energy   temp  rhum  wspd    pres
# 0    32.8  14.95  93.0  13.9  1001.8
# 1    33.0  14.80  92.0  14.8  1001.7
# 2     5.9  14.75  91.5  13.9  1001.7
# 3    32.7  14.75  91.5  13.9  1001.7
# 4    32.2  14.70  91.0  13.0  1001.7

# %% [markdown]
# ##### Second Model
#
# Day of week as a feature, hour and day of year.

# %%
df2 = df[['energy', 'temp', 'rhum', 'wspd', 'pres', 'time']]
df2.loc[:, 'dayofweek'] = df2['time'].dt.dayofweek
df2.loc[:, 'hour'] = df2['time'].dt.hour
df2.loc[:, 'dayofyear'] = df2['time'].dt.dayofyear
df2.drop(['time'], axis=1, inplace=True)
df2.head()
# Out:
#    energy   temp  rhum  wspd    pres  dayofweek  hour  dayofyear
# 0    32.8  14.95  93.0  13.9  1001.8          6     0        274
# 1    33.0  14.80  92.0  14.8  1001.7          6     1        274
# 2     5.9  14.75  91.5  13.9  1001.7          6     1        274
# 3    32.7  14.75  91.5  13.9  1001.7          6     1        274
# 4    32.2  14.70  91.0  13.0  1001.7          6     2        274

# %% [markdown]
# ##### Third Model
#
# Is weekend as a feature, hour and day of year.

# %%
df3 = df[['energy', 'time', 'temp', 'rhum', 'wspd', 'pres']]
df3.loc[:, 'is_weekend'] = df3['time'].dt.dayofweek.isin([5, 6])
df3.loc[:, 'hour'] = df3['time'].dt.hour
df3.loc[:, 'dayofyear'] = df3['time'].dt.dayofyear
df3.drop(['time'], axis=1, inplace=True)
df3.head()
# Out:
#    energy   temp  rhum  wspd    pres  is_weekend  hour  dayofyear
# 0    32.8  14.95  93.0  13.9  1001.8        True     0        274
# 1    33.0  14.80  92.0  14.8  1001.7        True     1        274
# 2     5.9  14.75  91.5  13.9  1001.7        True     1        274
# 3    32.7  14.75  91.5  13.9  1001.7        True     1        274
# 4    32.2  14.70  91.0  13.0  1001.7        True     2        274

# %% [markdown]
# ##### Fourth Model
#
# Use the last 24 hours data.

# %%
df4 = df[['energy', 'temp', 'rhum', 'wspd', 'pres', 'time', 'location']]

df4 = df4.groupby(['time', 'location']).mean().reset_index().sort_values(['location', 'time'])

# the data is half hourly, so we need the last 48 rows
for i in range(1, 49):
    df4[f'energy_{i}'] = df4.shift(i)['energy']

df4.head()
# Out:
#                      time                                     location  \
# 78311 2008-06-14 00:30:00  ## OLD Paulton Library Electricity Supply 1
# 78321 2008-06-14 01:00:00  ## OLD Paulton Library Electricity Supply 1
# 78346 2008-06-14 02:30:00  ## OLD Paulton Library Electricity Supply 1
# 78355 2008-06-14 03:00:00  ## OLD Paulton Library Electricity Supply 1
# 78374 2008-06-14 04:00:00  ## OLD Paulton Library Electricity Supply 1
#
#        energy  temp  rhum  wspd     pres  energy_1  energy_2  energy_3  ...  \
# 78311    0.08   9.6  81.0  11.2  1017.75       NaN       NaN       NaN  ...
# 78321    0.07   9.6  81.0   9.4  1017.60      0.08       NaN       NaN  ...
# 78346    0.08   9.1  81.0   7.6  1017.45      0.07      0.08       NaN  ...
# 78355    0.07   8.6  81.0   7.6  1017.40      0.08      0.07      0.08  ...
# 78374    0.07   8.6  81.0   5.4  1016.90      0.07      0.08      0.07  ...
#
#        energy_39  energy_40  energy_41  energy_42  energy_43  energy_44  \
# 78311        NaN        NaN        NaN        NaN        NaN        NaN
# 78321        NaN        NaN        NaN        NaN        NaN        NaN
# 78346        NaN        NaN        NaN        NaN        NaN        NaN
# 78355        NaN        NaN        NaN        NaN        NaN        NaN
# 78374        NaN        NaN        NaN        NaN        NaN        NaN
#
#        energy_45  energy_46  energy_47  energy_48
# 78311        NaN        NaN        NaN        NaN
# 78321        NaN        NaN        NaN        NaN
# 78346        NaN        NaN        NaN        NaN
# 78355        NaN        NaN        NaN        NaN
# 78374        NaN        NaN        NaN        NaN
#
# [5 rows x 55 columns]

# %%
df4_copy = df4.copy()

# for the first 48 values of each location, drop the first rows
# they don't have the correct values
# since they are either NaN or of other locations

locations = df4['location'].unique()
rows_to_delete = []

for location in locations:
    rows_to_delete.append(df4[df4['location'] == location].index[:48])

rows_to_delete = [i for index in rows_to_delete for i in index]
# drop rows, rows_to_delete contains their index
df4_copy.drop(rows_to_delete, inplace=True)

# %%
df4 = df4_copy

df4.drop(['time', 'location'], axis=1, inplace=True)
df4.head()
# Out:
#        energy  temp  rhum  wspd     pres  energy_1  energy_2  energy_3  \
# 78994    0.08  16.6  57.5  11.2  1010.70      0.08      0.08      0.08
# 79002    0.08  17.6  52.0  11.2  1010.60      0.08      0.08      0.08
# 79011    0.08  16.6  59.5  13.0  1010.45      0.08      0.08      0.08
# 79028    0.08  15.6  65.0  12.1  1010.25      0.08      0.08      0.08
# 79037    0.08  15.6  63.0   9.4  1010.20      0.08      0.08      0.08
#
#        energy_4  energy_5  ...  energy_39  energy_40  energy_41  energy_42  \
# 78994      0.08      0.08  ...       0.07       0.07       0.08       0.08
# 79002      0.08      0.08  ...       0.44       0.07       0.07       0.08
# 79011      0.08      0.08  ...       0.38       0.44       0.07       0.07
# 79028      0.08      0.08  ...       0.56       0.38       0.44       0.07
# 79037      0.08      0.08  ...       0.91       0.56       0.38       0.44
#
#        energy_43  energy_44  energy_45  energy_46  energy_47  energy_48
# 78994       0.08       0.07       0.07       0.08       0.07       0.08
# 79002       0.08       0.08       0.07       0.07       0.08       0.07
# 79011       0.08       0.08       0.08       0.07       0.07       0.08
# 79028       0.07       0.08       0.08       0.08       0.07       0.07
# 79037       0.07       0.07       0.08       0.08       0.08       0.07
#
# [5 rows x 53 columns]

# %% [markdown]
# ##### Fifth Model
#
# Use the last 5-10 days of data from the same time.

# %%
df5 = df[['energy', 'temp', 'rhum', 'wspd', 'pres', 'time', 'location']]

df5 = df5.groupby(['time', 'location']).mean().reset_index().sort_values(['location', 'time'])

for i in range(1, 11):
    # shift 10 days
    df5[f'energy_{i}'] = df5.shift(i * 48)['energy']

df5.head()
# Out:
#                      time                                     location  \
# 78311 2008-06-14 00:30:00  ## OLD Paulton Library Electricity Supply 1
# 78321 2008-06-14 01:00:00  ## OLD Paulton Library Electricity Supply 1
# 78346 2008-06-14 02:30:00  ## OLD Paulton Library Electricity Supply 1
# 78355 2008-06-14 03:00:00  ## OLD Paulton Library Electricity Supply 1
# 78374 2008-06-14 04:00:00  ## OLD Paulton Library Electricity Supply 1
#
#        energy  temp  rhum  wspd     pres  energy_1  energy_2  energy_3  \
# 78311    0.08   9.6  81.0  11.2  1017.75       NaN       NaN       NaN
# 78321    0.07   9.6  81.0   9.4  1017.60       NaN       NaN       NaN
# 78346    0.08   9.1  81.0   7.6  1017.45       NaN       NaN       NaN
# 78355    0.07   8.6  81.0   7.6  1017.40       NaN       NaN       NaN
# 78374    0.07   8.6  81.0   5.4  1016.90       NaN       NaN       NaN
#
#        energy_4  energy_5  energy_6  energy_7  energy_8  energy_9  energy_10
# 78311       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 78321       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 78346       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 78355       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 78374       NaN       NaN       NaN       NaN       NaN       NaN        NaN

# %%
locations = df5['location'].unique()
rows_to_delete = []

for i in tqdm(range(len(locations))):
    location = locations[i]
    # get the first 10 days of each location
    rows_to_delete.append(df5[df5['location'] == location].index[:10 * 48])

rows_to_delete = [i for index in rows_to_delete for i in index]
# Out:
# 100%|██████████| 72/72 [00:17<00:00,  4.17it/s]

# %%
# drop rows, rows_to_delete contains their index
df5.drop(rows_to_delete, inplace=True)

df5.drop(['time', 'location'], axis=1, inplace=True)
df5.head()
# Out:
#        energy  temp  rhum  wspd     pres  energy_1  energy_2  energy_3  \
# 84869    0.08  15.1  79.5  36.9  1017.30      0.07      0.08      0.08
# 84886    0.08  14.6  82.0  29.5  1017.70      0.08      0.07      0.07
# 84893    0.07  14.6  82.0  27.7  1017.90      0.08      0.08      0.08
# 84902    0.08  14.1  85.0  25.0  1018.25      0.07      0.09      0.08
# 84912    0.08  13.6  88.0  22.3  1018.60      0.08      0.08      0.07
#
#        energy_4  energy_5  energy_6  energy_7  energy_8  energy_9  energy_10
# 84869      0.08      0.08      0.08      0.08      0.07      0.08       0.08
# 84886      0.08      0.08      0.07      0.08      0.08      0.08       0.07
# 84893      0.08      0.08      0.07      0.08      0.08      0.08       0.08
# 84902      0.08      0.07      0.23      0.08      0.07      0.08       0.07
# 84912      0.07      0.08      0.60      0.08      0.08      0.08       0.07

# %%
# save the files to pickle
df1.to_pickle('df1.pkl')
df2.to_pickle('df2.pkl')
df3.to_pickle('df3.pkl')
df4.to_pickle('df4.pkl')
df5.to_pickle('df5.pkl')

# %% [markdown]
# ## Build the models
#
# In this section, we will create and train the XGBoost models.
#
#
# #### First Model

# %%
# load the files from pickle
df1: pd.DataFrame = pd.read_pickle('df1.pkl')

y_cols = ['energy']
X_cols = ['temp', 'rhum', 'wspd', 'pres']

X_train, X_test, y_train, y_test = pre_processing(df1, X_cols, y_cols, test_size=0.2)

# %%
_, preds = build_model(X_train, y_train, X_test)
# Out:
# /home/mcmatos/.local/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
plt.figure(figsize=(12, 8))

plot_results(preds, y_test, 'XGBoost 1')

# %%
performance_metrics(preds, y_test)
# Out:
# MSE: 72.0691
# RMSE: 8.4894
# MAE: 5.0448
# R2: 0.0085

# %% [markdown]
# ### Second Model

# %%
# load the files from pickle
df2: pd.DataFrame = pd.read_pickle('df2.pkl')

# X_cols is all the columns except the energy
X_cols = df2.columns.difference(['energy'])
y_cols = ['energy']

X_train, X_test, y_train, y_test = pre_processing(df2, X_cols, y_cols)

# %%
_, preds = build_model(X_train, y_train, X_test)
# Out:
# /home/mcmatos/.local/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [23:50:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:50:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=5
# [23:51:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5

# %%
plt.figure(figsize=(12, 8))

plot_results(preds, y_test, 'XGBoost 2')

# %%
performance_metrics(preds, y_test)
# Out:
# MSE: 49.7276
# RMSE: 7.0518
# MAE: 4.6161
# R2: -0.0911

# %% [markdown]
# ### Third Model

# %%
# load the files from pickle
df3: pd.DataFrame = pd.read_pickle('df3.pkl')

# X_cols is all the columns except the energy
X_cols = df3.columns.difference(['energy'])
y_cols = ['energy']

X_train, X_test, y_train, y_test = pre_processing(df3, X_cols, y_cols, random=True)

# %%
# build the model
_, preds = build_model(X_train, y_train, X_test)
# Out:
# /home/mcmatos/.local/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
plt.figure(figsize=(12, 8))

plot_results(preds, y_test, 'XGBoost 3')

# %%
performance_metrics(preds, y_test)
# Out:
# MSE: 69.0163
# RMSE: 8.3076
# MAE: 4.8811
# R2: 0.0505

# %% [markdown]
# ### Fourth Model

# %%
# load the files from pickle
df4: pd.DataFrame = pd.read_pickle('df4.pkl')

X_cols = df4.columns.difference(['energy'])
y_cols = ['energy']

X_train, X_test, y_train, y_test = pre_processing(df4, X_cols, y_cols)

# %%
_, preds = build_model(X_train, y_train, X_test)
# Out:
# /home/mcmatos/.local/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
plt.figure(figsize=(12, 8))

plot_results(preds, y_test, 'XGBoost 4')

# %%
performance_metrics(preds, y_test)
# Out:
# MSE: 1.7758
# RMSE: 1.3326
# MAE: 0.5052
# R2: 0.9757

# %% [markdown]
# ### Fifth Model

# %%
# load the files from pickle
df5: pd.DataFrame = pd.read_pickle('df5.pkl')

X_cols = df5.columns.difference(['energy'])
y_cols = ['energy']

X_train, X_test, y_train, y_test = pre_processing(df5, X_cols, y_cols)

# %%
_, preds = build_model(X_train, y_train, X_test)
# Out:
# /home/mcmatos/.local/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
plt.figure(figsize=(12, 8))

plot_results(preds, y_test, 'XGBoost 5')

# %%
performance_metrics(preds, y_test)
# Out:
# MSE: 12.9097
# RMSE: 3.5930
# MAE: 1.7078
# R2: 0.8244
